# %% [markdown]
# # Merge Sorted Array

# %% [markdown]
# You are given two integer arrays `nums1` nad `nums2`, sorted in **non-decreasing order**, and two integers `m` and `n`, representing the number of elements in `nums1` and `nums2` respectively.
# **Merge** `nums1` and `nums2` into a single array sorted in **non-decreasing order**.
#
# The final sorted array should not be reutrned by the function, but instead be *sorted inside the array* `nums1`. To accomodate this, `nums1` has a length of `m + n`, where the first `m` elements denote the elements that should be merged, and the last `n` elements are set to `0` and should be ignored. `nums2` has a length of `n`.
#
#
# ```
# Example 1:
# Input: nums1 = [1,2,3,0,0,0], m = 3, nums2 = [2,5,6], n = 3
# Output: [1,2,2,3,5,6]
# Explanation: The arrays we are merging are [1,2,3] and [2,5,6].
# The result of the merge is [1,2,2,3,5,6] with the underlined elements coming from nums1.
#
# Example 2:
# Input: nums1 = [1], m = 1, nums2 = [], n = 0
# Output: [1]
# Explanation: The arrays we are merging are [1] and [].
# The result of the merge is [1].
#
# Example 3:
# Input: nums1 = [0], m = 0, nums2 = [1], n = 1
# Output: [1]
# Explanation: The arrays we are merging are [] and [1].
# The result of the merge is [1].
# Note that because m = 0, there are no elements in nums1. The 0 is only there to ensure the merge result can fit in nums1.
# ```

# %%
def merge(nums1, m, nums2, n):
    if m == 0: m = 1
    if n == 0: n = 1
    if len(nums1) == 0: nums1 = [0]
    if len(nums2) == 0: nums2 = [0]
    i, j = 0, 0
    while i < m:
        if j == n - 1:
            j = 0
        temp_1 = nums1[i]
        temp_2 = nums2[j]
        if temp_1 != 0 and temp_1 < temp_2:
            nums1[i] = temp_1
            #i += 1
        elif temp_2 != 0 and temp_2 < temp_1:
            nums1[i] = temp_2
            nums2[j] = temp_1
            j += 1
        elif temp_2 > temp_1:
            nums1[i] = temp_2
            j += 1
        i += 1
    return nums1



def merge(nums1, m, nums2, n):
    if m == 0: m = 1
    if n == 0: n = 1
    if len(nums1) == 0: nums1 = [0]
    if len(nums2) == 0: nums2 = [0]
    new_list = []
    i, j, z = 0, 0, 0
    while z < m:
        if nums1[z] != 0:
            if nums1[i] < nums2[j]:
                new_list.append(nums1[i])
                i = i + 1
            else: 
                new_list.append(nums2[j])
                #if j < n - 1:
                j = j + 1
        else:
            new_list.append(nums2[j])
            #j += 1
            i += 1
        z += 1
    return new_list



def merge(nums1, m, nums2, n):
    if m == 0: m = 1
    if n == 0: n = 1
    if len(nums1) == 0: nums1 = [0]
    if len(nums2) == 0: nums2 = [0]
    for i, el in enumerate(nums1):
        if i != 0 and el == 0:
            nums1[i] = float('inf')
    i, j, z = 0, 0, 0
    temp1 = nums1[i]
    temp2 = nums2[j]
    while z < m:
        if temp1 < temp2:
            nums1[z] = temp1
            i += 1
            temp1 = nums1[i]
        elif temp2 < temp1:
            #temp1 = nums1[z]
            nums1[z] = temp2
            j += 1
            temp2 = nums2[j]
        z += 1
    return nums1


def merge(nums1, m, nums2, n):
    if m == 0: m = 1
    if n == 0: n = 1
    if len(nums1) == 0: nums1 = [0]
    if len(nums2) == 0: nums2 = [0]
    for i, el in enumerate(nums1):
        if i != 0 and el == 0:
            nums1[i] = float('inf')
    i, j, z = 0, 0, 0
    temp1 = nums1[i]
    temp2 = nums2[j]
    while z < m:
        if temp1 < temp2:
            nums1[z] = temp1
            i += 1
            temp1 = nums1[i]
        elif temp2 < temp1:
            #temp1 = nums1[z]
            nums1[z] = temp2
            j += 1
            temp2 = nums2[j]
        z += 1
    return nums1



def merge(nums1, m, nums2, n):
    if m == 0: m = 1
    if n == 0: n = 1
    if len(nums1) == 0: nums1 = [0]
    if len(nums2) == 0: nums2 = [0]
    #for i, el in enumerate(nums1):
    #    if (i != 0 and el == 0) or (len(nums1) == 1 and el == 0):
    #        nums1[i] = float('inf')
    i, j = 0, 0
    while i < m and j < n:
        if (nums2[j] != 0 and nums2[j] < nums1[i]) or (nums1[i] == 0 or (len(nums1) == 1 and nums1[i] == 0)):
            for z in range(m - 2, i - 1, -1):
                nums1[z + 1] = nums1[z]
            nums1[i] = nums2[j]
            j += 1
            i += 1         
        else:
            i += 1
    return nums1


def merge(nums1, m, nums2, n):
    i = 0 
    j = 0
    final_array = [0 for z in range(len(nums1))]
    for z in range(len(final_array)):
        # if (z != 0 and nums1[i] == 0):
        #     final_array[z] = nums2[j]
        #     if j < len(nums2):
        #         j += 1
        if nums1[i] < nums2[j]:
            final_array[z] = nums1[i]
            if i < len(nums1) - 1:
                i += 1
        elif nums2[j] < nums1[i] or (z != 0 and nums1[i] == 0):
            final_array[z] = nums2[j]
            if j < len(nums2) - 1:
                j += 1
            else: nums2[j] = float('inf')
    return final_array




nums1 = [1, 2, 3, 0, 0, 0]
nums2 = [2, 5, 6]
n = len(nums2)
m = len(nums1)

# nums1 = [1]
# nums2 = [0]
# m = 1
# n = 0

# nums1 = [4, 5, 6, 0, 0, 0]
# nums2 = [1, 2, 3]
# n = len(nums2)
# m = len(nums1)

# nums1 = [0,0,0,0,0]
# nums2 = [1,2,3,4,5]
# n = len(nums2)
# m = len(nums1)

print(merge(nums1, m, nums2, n))
# Out:
# [1, 0, 0, 0, 0, 0]
