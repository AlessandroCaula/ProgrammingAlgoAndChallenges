# %% [markdown]
# # Remove Nth Node From End of List
#
# Given the head of a linked list, remove the n-th node from the end of the list and return its head.
#
# #### Example 1:
#
# ![image.png](attachment:image.png)
#
# ```
# Input: head = [1,2,3,4,5], n = 2
# Output: [1,2,3,5]
# ```
#
# #### Example 2:
#
# ```
# Input: head = [1,2], n = 1
# Output: [1]
# ```

# %%
# LL node class
class ListNode():
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def create_ll_from_array(arr: list):
    curr = ListNode(arr[0], None)
    head = curr
    for el in arr[1:]:
        curr.next = ListNode(el, None)
        curr = curr.next
    return head

def remove_nth_node(ll: ListNode) -> ListNode:

    return 

# Create LL from array
create_ll_from_array([1,2,3,4,5])
